# %% [markdown]
# ***TAREA***

# %%
import pandas as pd
import numpy as np
import json as js
import csv
# %pip install openpyxl

victoriabc = pd.read_csv("Victoria BC.csv")
victoriabc
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#       Unnamed: 0                   id     scrape_id last_scraped  \
# 0              0                19898  2.024120e+13     29/12/24
# 1              1                41168  2.024120e+13     29/12/24
# 2              2                83515  2.024120e+13     29/12/24
# 3              3               168460  2.024120e+13     29/12/24
# 4              4               185732  2.024120e+13     29/12/24
# ...          ...                  ...           ...          ...
# 3946        3946  1315368084757533488  2.024120e+13     29/12/24
# 3947        3947  1316608634341666791  2.024120e+13     29/12/24
# 3948        3948  1317141084646533661  2.024120e+13     29/12/24
# 3949        3949  1318221712246054906  2.024120e+13     29/12/24
# 3950        3950  1318259877390189592  2.024120e+13     29/12/24
#
# ...

# %%
#(a) 5 host names

host_names = victoriabc['host_name']
datos_filtrados_a = victoriabc[victoriabc['host_name'].isin(host_names)]
datos_filtrados_a.to_csv("Victoria BC.csv", index=False)
host_names
# Out:
# 0                             Ryan
# 1       Ocean Island Garden Suites
# 2                            Celia
# 3                          Deborah
# 4                            Peter
#                    ...
# 3946                    Swell West
# 3947                Charlotte Jane
# 3948                     Majachani
# 3949                          Troy
# 3950          Elite Vacation Homes
# Name: host_name, Length: 3951, dtype: object

# %%
host_names.to_csv("Datos de Host_Names.csv")

# %%
# (b) Anuncios con más de 100 reseñas

if 'number_of_reviews' in victoriabc.columns:
    datosb = victoriabc[victoriabc['number_of_reviews'] > 100]
datosb
# Out:
#       Unnamed: 0                   id     scrape_id last_scraped  \
# 2              2                83515  2.024120e+13     29/12/24
# 5              5               193366  2.024120e+13     29/12/24
# 8              8               203416  2.024120e+13     29/12/24
# 9              9               226028  2.024120e+13     29/12/24
# 11            11               237053  2.024120e+13     29/12/24
# ...          ...                  ...           ...          ...
# 2699        2699   887793960658346125  2.024120e+13     29/12/24
# 2792        2792   908960583232600673  2.024120e+13     29/12/24
# 3015        3015   978366514419795869  2.024120e+13     29/12/24
# 3021        3021   979957999730575703  2.024120e+13     29/12/24
# 3112        3112  1008885829311227831  2.024120e+13     29/12/24
#
#                                          host_url             host_location  \
# 2        https://www.airbnb.com/users/show/455118  British Columbia, Canada
# ...

# %%
datosb.to_csv("Datos Anuncios > 100 reseñas.csv", index=False)

# %%
# (c) 

if 'host_is_superhost' in victoriabc.columns:
    datosc = victoriabc[victoriabc['host_is_superhost'] == 't']
else:
    print("Advertencia: la columna 'host_is_superhost' no se encontró. Se omite el filtro 'super_host'.")

# %%
datosc.to_csv("Datos Super Host.csv", index=False)

# %%
# d) Rows multiples of 200

datosd = victoriabc.iloc[::200]

# %%
datosd.to_csv("Datos filtro filas.csv", index=False)

# %%
# e) Room types: "Entire home" and "Private room"
if 'property_type' in victoriabc.columns:
    datose = ['Entire home', 'Private room']

print('property_type' in victoriabc.columns)
# Out:
# True

# %%
datose.to_csv("Datos tipos de cuarto.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 datose.to_csv("Datos tipos de cuarto.csv", index=False)
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
# f) Maximum 4 beds
if 'beds' in victoriabc.columns:
    datosf = victoriabc[victoriabc['beds'] <= 4]

# %%
datosf.to_csv("Datos maximo 4 camas.csv", index=False)

# %%
# g) Instant bookable
if 'has_availability' in victoriabc.columns:
    datosg = victoriabc[victoriabc['has_availability'] == 't']
print('has_availability' in victoriabc.columns)
# Out:
# True

# %%
datosg.to_csv("Datos Instant .csv", index=False)

# %%
# h) Odd columns
victoriabc.iloc[:, ::2]
# Out:
#       Unnamed: 0     scrape_id                                     host_url  \
# 0              0  2.024120e+13      https://www.airbnb.com/users/show/69729
# 1              1  2.024120e+13     https://www.airbnb.com/users/show/173169
# 2              2  2.024120e+13     https://www.airbnb.com/users/show/455118
# 3              3  2.024120e+13     https://www.airbnb.com/users/show/802981
# 4              4  2.024120e+13     https://www.airbnb.com/users/show/880366
# ...          ...           ...                                          ...
# 3946        3946  2.024120e+13  https://www.airbnb.com/users/show/548256873
# 3947        3947  2.024120e+13  https://www.airbnb.com/users/show/668062525
# 3948        3948  2.024120e+13  https://www.airbnb.com/users/show/290549710
# 3949        3949  2.024120e+13  https://www.airbnb.com/users/show/112019210
# 3950        3950  2.024120e+13   https://www.airbnb.com/users/show/32614142
#
# ...

# %%
victoriabc.to_csv("Datos impares.csv", index=False)

# %% [markdown]
# ***Actividad 2***

# %%
# a) Acceptance rate and super host

print(victoriabc['host_acceptance_rate'].dtype)
# Out:
# float64

# %%
victoriabc['host_acceptance_rate'] = victoriabc['host_acceptance_rate'].str.replace('%', '').astype(float)

# %%
victoriabc['host_is_superhost'] = victoriabc['host_is_superhost'].map({'True': True, 'False': False})

# %%
victoriabc['host_is_superhost'] = victoriabc['host_is_superhost'].astype(bool)

# %%
print(victoriabc['host_is_superhost'].dtype)
# Out:
# bool

# %%
datosa2 = victoriabc[(victoriabc['host_acceptance_rate'] > 95) & (~victoriabc['host_is_superhost'])]
datosa2
# Out:
# Empty DataFrame
# ...

# %%
datosa2.to_csv("Datos Rate Superhost.csv", index=False)

# %%
#b) 1 baño

datosbaño = victoriabc[victoriabc['bathrooms'] != 1]
datosbaño
# Out:
#       Unnamed: 0                   id     scrape_id last_scraped  \
# 0              0                19898  2.024120e+13     29/12/24
# 3              3               168460  2.024120e+13     29/12/24
# 5              5               193366  2.024120e+13     29/12/24
# 10            10               226030  2.024120e+13     29/12/24
# 17            17               408315  2.024120e+13     29/12/24
# ...          ...                  ...           ...          ...
# 3913        3913  1302997863073985323  2.024120e+13     29/12/24
# 3918        3918  1303278477790226126  2.024120e+13     29/12/24
# 3929        3929  1309774171835273959  2.024120e+13     29/12/24
# 3937        3937  1312530336729382434  2.024120e+13     29/12/24
# 3944        3944  1314683517774131164  2.024120e+13     29/12/24
#
#                                          host_url     host_location  \
# 0         https://www.airbnb.com/users/show/69729               NaN
# ...

# %%
datosa2.to_csv("Datos 1 bathroom.csv", index=False)

# %%
#c) Precios entre 100 y 200
print(victoriabc['price'].dtype)
# Out:
# object

# %%
victoriabc['price'] = victoriabc['price'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
datosc2 = victoriabc[(victoriabc['price'] >= 100) & (victoriabc['price'] <= 200)]

# %%
datosc2 = victoriabc[(victoriabc['price'] >= 100) & (victoriabc['price'] <= 200)]
datosc2
# Out:
#       Unnamed: 0                   id     scrape_id last_scraped  \
# 2              2                83515  2.024120e+13     29/12/24
# 3              3               168460  2.024120e+13     29/12/24
# 4              4               185732  2.024120e+13     29/12/24
# 5              5               193366  2.024120e+13     29/12/24
# 7              7               201441  2.024120e+13     29/12/24
# ...          ...                  ...           ...          ...
# 3942        3942  1314652550456408670  2.024120e+13     29/12/24
# 3943        3943  1314652726394086067  2.024120e+13     29/12/24
# 3944        3944  1314683517774131164  2.024120e+13     29/12/24
# 3947        3947  1316608634341666791  2.024120e+13     29/12/24
# 3950        3950  1318259877390189592  2.024120e+13     29/12/24
#
#                                          host_url             host_location  \
# 2        https://www.airbnb.com/users/show/455118  British Columbia, Canada
# ...

# %%
datosc2.to_csv("Datos Price.csv", index=False)

# %%
#d) Total listings
datosd2 = victoriabc[victoriabc['host_total_listings_count'] > 5]
datosd2
# Out:
#       Unnamed: 0                   id     scrape_id last_scraped  \
# 1229        1229             40122004  2.024120e+13     29/12/24
# 1434        1434             45314164  2.024120e+13     29/12/24
# 1622        1622             49534925  2.024120e+13     29/12/24
# 1624        1624             49590174  2.024120e+13     29/12/24
# 1625        1625             49590710  2.024120e+13     29/12/24
# 1626        1626             49591308  2.024120e+13     29/12/24
# 1636        1636             49877269  2.024120e+13     29/12/24
# 2409        2409   764803845156113357  2.024120e+13     29/12/24
# 2765        2765   903489069957681570  2.024120e+13     29/12/24
# 3440        3440  1152823290309144196  2.024120e+13     29/12/24
#
#                                          host_url     host_location  \
# 1229  https://www.airbnb.com/users/show/297265233               NaN
# 1434   https://www.airbnb.com/users/show/34315109  Victoria, Canada
# ...

# %%
datosd2.to_csv("Datos Total Listings.csv", index=False)

# %%
#e)
datose2 = victoriabc[victoriabc['property_type'].isin(['hotel room', 'Private room'])]
victoriabc
# Out:
#       Unnamed: 0                   id     scrape_id last_scraped  \
# 334          334             12925681  2.024120e+13     29/12/24
# 1066        1066             35317460  2.024120e+13     29/12/24
# 1229        1229             40122004  2.024120e+13     29/12/24
# 1434        1434             45314164  2.024120e+13     29/12/24
# 1622        1622             49534925  2.024120e+13     29/12/24
# 1624        1624             49590174  2.024120e+13     29/12/24
# 1625        1625             49590710  2.024120e+13     29/12/24
# 1626        1626             49591308  2.024120e+13     29/12/24
# 1636        1636             49877269  2.024120e+13     29/12/24
# 2130        2130   646526684625362269  2.024120e+13     29/12/24
# 2409        2409   764803845156113357  2.024120e+13     29/12/24
# 2765        2765   903489069957681570  2.024120e+13     29/12/24
# 3440        3440  1152823290309144196  2.024120e+13     29/12/24
#
# ...

# %%
datose2.to_csv("Datos 'Hotel' 'Private'.csv", index=False)

# %%
#f) 2 > bedrooms
datosf2 = victoriabc[victoriabc['availability_365'] > 300]
datosf2
# Out:
#       Unnamed: 0                  id     scrape_id last_scraped  \
# 1434        1434            45314164  2.024120e+13     29/12/24
# 2765        2765  903489069957681570  2.024120e+13     29/12/24
#
#                                         host_url     host_location  \
# 1434  https://www.airbnb.com/users/show/34315109  Victoria, Canada
# 2765  https://www.airbnb.com/users/show/34315109  Victoria, Canada
#
#       host_acceptance_rate  host_is_superhost  host_total_listings_count  \
# 1434                  54.0               True                         45
# 2765                  54.0               True                         45
#
#       host_verifications  ...  calculated_host_listings_count  \
# 1434  ['email', 'phone']  ...                              29
# 2765  ['email', 'phone']  ...                              29
#
#      calculated_host_listings_count_entire_homes  \
# 1434                                           0
# 2765                                           0
#
# ...

# %%
datosf2.to_csv("Datos Availability.csv", index=False)
